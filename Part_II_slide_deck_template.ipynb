# %% [markdown]
# ## Part II - Communicate_Data_Findings
# ## by Maurício de Assis Domingues

# %% [markdown]
# ## Investigation Overview
#
#
# I am interested in collecting information related to travel time and the relationship with gender, age, customer or subscriber.
# Analyze variables and look for correlations between distributions, collect information and generate insights about the dataframe. Check how the system works and collect relevant information for the analysis of the bike sharing system and how the public that uses this means of transport is formed.
#
#
# ## Dataset Overview
#
# This data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area. The Bike Share for All Trip bike-sharing system was launched by Ford GoBike in the San Francisco Bay Area in 2017 in partnership with the Metropolitan Transportation Commission and Bay Area Bike Share. .

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df_clean = pd.read_csv('Communicate_Data_Findings_notebook.csv')

# %% [markdown]
# ## 1 - Days of week with more users
#
# Thursdays have the highest number of users, followed by Tuesdays and Wednesdays.

# %%
plt.figure(figsize = [15, 5])
bluesteel = sb.color_palette()[0]
sb.countplot(data=df_clean, x='start_time_dayofweek', color=bluesteel)
plt.title('Days of the week with more users')
# Out:
# Text(0.5,1,'Days of the week with more users')

# %% [markdown]
# # 2 - Hours throught the day with more users
# Throughout the day, we have two peaks in the use of bikes. The first takes place around 8 am and the second at 5 pm.

# %%
plt.figure(figsize = [15, 5])
p1 = sb.countplot(data = df_clean, x = 'start_time_hour', color = bluesteel)
plt.title('Hours throughout the day with more users')
# Out:
# Text(0.5,1,'Hours throughout the day with more users')

# %% [markdown]
# ## 3 - Distribution between age and duration of trip
#
# Distribution has an average close to 9 minutes of bike use; between 25 and 30 years old users and the correlation between age and duration presented by the graph shows us an accumulation of data between 3 to 21 minutes of trip and between users who are between 21 and 39 years old.

# %%
# scatter plot of duration_min vs. member_age, with log transform on duration_min axis
samples = np.random.choice(df_clean.shape[0], 5000, replace = False)
df_clean_samp = df_clean.loc[samples,:]

plt.figure(figsize = [15, 5]);
plt.scatter(data = df_clean_samp, x = 'member_age', y = 'duration_min', alpha = 1/10);
#plt.xlim([0, 3.5])
plt.xlabel('Member Age');
plt.yscale('log');
plt.yticks([1, 2, 5, 10, 20, 50, 100], [1, 2, 5, 10, 20, 50, 100]);
plt.title("Distribution between age and duration of trip")
plt.ylabel('Duration (min)');

plt.figure(figsize = [15, 5])
plt.scatter(data = df_clean_samp, x = 'member_age', y = 'duration_min', alpha = 1/10)
plt.xlabel('Member Age')
plt.yscale('log')
plt.yticks([1, 2, 5, 10, 20, 50, 100], [1, 2, 5, 10, 20, 50, 100])
plt.ylabel('Duration (min)')

# Add vertical line for average member_age
plt.axvline(df_clean_samp['member_age'].mean(), color='red', linestyle='--', label='Mean member age')

# # Add horizontal line to the median of duration_min
plt.axhline(df_clean_samp['duration_min'].median(), color='red', linestyle='--', label='Median duration')
plt.title("Distribution between age and duration of trip - with line")
plt.legend()

# %% [markdown]
# ## 4 - Distribution between age and gender
# The correlation between age and gender presents some peculiarities: male presents a distribution that increases up to 25 years old and, in sequence, an arc that decreases at first and then increases again up to 30 years old, from this point onwards there is a smooth reduction up to 40 years old years of age and in the strongest sequence up to 60 years of age; Females, on the other hand, grow progressively up to 27 years of age and then start a smooth decline up to 41 years of age, increasing in level up to 60 years of age with some variations between 50 and 55 years of age; Others show a strong increase up to 30 and then decrease to 44, showing a growth again up to 55 and then decrease up to 60.years.

# %%
plt.figure(figsize = (10,3), dpi = 100)

bluesteel = sb.color_palette()[0]
sb.violinplot(data=df_clean,x = "member_gender", y = "member_age", color=bluesteel)
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title("Distribution between Age and Gender")
# Out:
# Text(0.5,1,'Distribution between Age and Gender')

# %%
# Use this command if you are running this file in local
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 561521 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_slide_deck_template.slides.html
# Use Control-C to stop this server
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: x-www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: firefox: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: iceweasel: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: seamonkey: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: mozilla: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: epiphany: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: konqueror: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: chromium-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: google-chrome: not found
# ...
